# %% [markdown]
# # CNN for many subjects

# %%
# %pylab
# %matplotlib inline

import glob
import os
import mne
CORPORA_PATH = "~/corpora/sets"

file_path = os.path.expanduser(CORPORA_PATH)
files = glob.glob(os.path.join(file_path, "*.set"))

def normalize_subject(X):
    mean = X.mean(axis=(0, 2)).reshape(-1, 1)
    std = X.std(axis=(0, 2)).reshape(-1, 1)
    return (X - mean) / std

def load_data(filename, normalize=True):
    data_mne = mne.io.read_raw_eeglab(filename, preload=True, event_id={"0": 1, "1": 2})
    data_mne.filter(0, 20)
    events = mne.find_events(data_mne)
    epochs = mne.Epochs(
        data_mne, events,
        baseline=(None, 0), tmin=-0.1, tmax=0.7)

    epochs.load_data()
    
    ch_names = epochs.ch_names
    
    X = epochs.get_data()[:, :-1]
    y = (events[:, 2] == 2).astype('float')

    if len(events) != len(epochs):
        raise ValueError("Epochs events mismatch")
    if normalize: 
        X = normalize_subject(X)
    
    
    return X, y, ch_names
# Out:
# Using matplotlib backend: TkAgg
# Populating the interactive namespace from numpy and matplotlib

# %%
len(files)
# Out:
# 145

# %%
channels = []
last = None

for file in files:
    try:
        _, _, ch_names = load_data(file)
        print(ch_names)
        
        if last is None:
            last = ch_names
        elif last != ch_names:
            raise "There was an error! {} different from {}".format(last, ch_names)
    except ValueError as e:
        print(e)
# Out:
# Reading /home/jmperez/corpora/sets/PruebasMuseo_29426001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_12521001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_14023001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_18531001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_16893001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_945001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_23794001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_1414001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_5568001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27946001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_25922001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27163001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_10229001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_16683001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_24540001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_17674001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_23298001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27030001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27408001.fdt
# Reading 0 ... 32219  =      0.000 ...   251.711 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 907 events found
# Events id: [1 2]
# 907 matching events found
# 0 projection items activated
# Loading data for 907 events and 104 original time points ...
# 2 bad epochs dropped
# Epochs events mismatch
# Reading /home/jmperez/corpora/sets/PruebasMuseo_24888001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_20668001.fdt
# Reading 0 ... 31895  =      0.000 ...   249.180 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 900 events found
# Events id: [1 2]
# 900 matching events found
# 0 projection items activated
# Loading data for 900 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_1635001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_13431001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27157001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_24053001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_11632001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_1609001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_29789001.fdt
# Reading 0 ... 31911  =      0.000 ...   249.305 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 900 events found
# Events id: [1 2]
# 900 matching events found
# 0 projection items activated
# Loading data for 900 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_8762001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_16943001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_26715001.fdt
# Reading 0 ... 31927  =      0.000 ...   249.430 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 900 events found
# Events id: [1 2]
# 900 matching events found
# 0 projection items activated
# Loading data for 900 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_36001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_7615001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_19561001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_29164001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_32459001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_16779001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_26721001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_2215001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_22109001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_9689001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_499001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_20947001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_15641001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_31397001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_3703001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_25217001.fdt
# Reading 0 ... 31871  =      0.000 ...   248.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 900 events found
# Events id: [1 2]
# 900 matching events found
# 0 projection items activated
# Loading data for 900 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_11551001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_14998001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_29063004.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_29257001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_20688001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_5510001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_24227001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_23732001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_9503001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_13252001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_4824001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_16637001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_7330001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_630001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_29273001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_21601001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_28301001.fdt
# Reading 0 ... 32059  =      0.000 ...   250.461 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 902 events found
# Events id: [1 2]
# 902 matching events found
# 0 projection items activated
# Loading data for 902 events and 104 original time points ...
# 2 bad epochs dropped
# Epochs events mismatch
# Reading /home/jmperez/corpora/sets/PruebasMuseo_11693001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_16266001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_18112001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_25302001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_22072001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27496001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_12702001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27131001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_12137001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_5857001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_3109001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_17435001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_6830001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_10882001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_8834001.fdt
# Reading 0 ... 31955  =      0.000 ...   249.648 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 900 events found
# Events id: [1 2]
# 900 matching events found
# 0 projection items activated
# Loading data for 900 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27846001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_7488001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_10924001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_12168001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_13235001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_5224001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_18077001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_15424001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_23272001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_25871001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_31102001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_17005001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_24101001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_21011001.fdt
# Reading 0 ... 67495  =      0.000 ...   527.305 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1930 events found
# Events id: [1 2]
# 1930 matching events found
# 0 projection items activated
# Loading data for 1930 events and 104 original time points ...
# 3 bad epochs dropped
# Epochs events mismatch
# Reading /home/jmperez/corpora/sets/PruebasMuseo_4305001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_3195001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_13640002.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_19491001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_9809001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_5251001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_22650001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_3942001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_17436001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_31777001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_12900001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_21120001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_232001.fdt
# Reading 0 ... 31903  =      0.000 ...   249.242 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 900 events found
# Events id: [1 2]
# 900 matching events found
# 0 projection items activated
# Loading data for 900 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_18306001.fdt
# Reading 0 ... 73547  =      0.000 ...   574.586 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2103 events found
# Events id: [1 2]
# 2103 matching events found
# 0 projection items activated
# Loading data for 2103 events and 104 original time points ...
# 3 bad epochs dropped
# Epochs events mismatch
# Reading /home/jmperez/corpora/sets/PruebasMuseo_17962001.fdt
# Reading 0 ... 88319  =      0.000 ...   689.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2520 events found
# Events id: [1 2]
# 2520 matching events found
# 0 projection items activated
# Loading data for 2520 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_7610001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_3800001.fdt
# Reading 0 ... 31943  =      0.000 ...   249.555 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 900 events found
# Events id: [1 2]
# 900 matching events found
# 0 projection items activated
# Loading data for 900 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_23344001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_18967001.fdt
# Reading 0 ... 31871  =      0.000 ...   248.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 900 events found
# Events id: [1 2]
# 900 matching events found
# 0 projection items activated
# Loading data for 900 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_18046001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_10729001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_30243001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_19845001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_22337001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_13863001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_4949001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_2681001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_27058001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_16003001.fdt
# Reading 0 ... 94591  =      0.000 ...   738.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 2700 events found
# Events id: [1 2]
# 2700 matching events found
# 0 projection items activated
# Loading data for 2700 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_21668001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_358001.fdt
# Reading 0 ... 63231  =      0.000 ...   493.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1800 events found
# Events id: [1 2]
# 1800 matching events found
# 0 projection items activated
# Loading data for 1800 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']
# Reading /home/jmperez/corpora/sets/PruebasMuseo_2109001.fdt
# Reading 0 ... 69503  =      0.000 ...   542.992 secs...
# Setting up low-pass filter at 20 Hz
# h_trans_bandwidth chosen to be 5.0 Hz
# Filter length of 169 samples (1.320 sec) selected
# 1980 events found
# Events id: [1 2]
# 1980 matching events found
# 0 projection items activated
# Loading data for 1980 events and 104 original time points ...
# 0 bad epochs dropped
# ['AF3', 'F7', 'F3', 'FC5', 'T7', 'P7', 'O1', 'O2', 'P8', 'T8', 'FC6', 'F4', 'F8', 'AF4', 'STI 014']

# %% [markdown]
# We can see that channels are in the same order for every subject
